# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

motor_train = pd.read_csv('motor_train.csv')
motor_test = pd.read_csv('motor_test.csv')

motor_train.head(10)
motor_test.head(10)
# Out:
#    class     peak   trough      mean       RMS  Crest_Factor
# 0      1  0.50823 -0.45133  0.151352  0.187720      2.707387
# 1      1  0.50823 -0.48971  0.156289  0.192089      2.645803
# 2      1  0.39308 -0.45133  0.163987  0.202870      1.937596
# 3      1  0.39308 -0.56647  0.167843  0.211949      1.854599
# 4      1  0.39473 -0.44968  0.164167  0.202855      1.945871
# 5      1  0.39473 -0.56483  0.168229  0.211970      1.862199
# 6      1  0.39473 -0.60321  0.185904  0.231504      1.705069
# 7      1  0.43311 -0.60321  0.185154  0.232290      1.864521
# 8      1  0.39308 -0.60486  0.185633  0.231502      1.697954
# 9      1  0.43146 -0.60486  0.184883  0.232321      1.857169

# %%
# 상관 관계 계산
correlation_matrix = motor_train.corr()

# 히트맵으로 상관 관계 시각화
plt.figure(figsize=(12, 8))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', linewidths=2)

# 그래프 타이틀 및 라벨 설정
plt.title('Feature Correlation Matrix')
plt.xlabel('Features')
plt.ylabel('Features')

# 그래프 보여주기
plt.show()

# %%
# 상관 관계 계산
correlation_matrix = motor_test.corr()

# 히트맵으로 상관 관계 시각화
plt.figure(figsize=(12, 8))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', linewidths=2)

# 그래프 타이틀 및 라벨 설정
plt.title('Feature Correlation Matrix')
plt.xlabel('Features')
plt.ylabel('Features')

# 그래프 보여주기
plt.show()

# %%
from sklearn.neural_network import MLPClassifier
from sklearn.preprocessing import StandardScaler, MinMaxScaler
from sklearn.model_selection import train_test_split
from sklearn.metrics import recall_score, accuracy_score, precision_score, f1_score, confusion_matrix, roc_curve, auc, classification_report

x_train = motor_train.drop("class", axis=1)
y_train = motor_train["class"]
x_test = motor_test.drop("class", axis=1)
y_test = motor_test["class"]


#model Create
model = MLPClassifier(hidden_layer_sizes=(100,), max_iter=300, alpha=1e-4,
                     solver='sgd', verbose=10, random_state=13, learning_rate_init=0.1)

model.fit(x_train, y_train)
y_pred = model.predict(x_test)

#Logistic Regression model verification
accuracy = accuracy_score(y_test, y_pred)
recall = recall_score(y_test, y_pred)
precision = precision_score(y_test, y_pred)
f1 = f1_score(y_test, y_pred)
conf_matrix = confusion_matrix(y_test, y_pred)
clas_report = classification_report(y_test, y_pred)

print(accuracy)
print(recall)
print(precision)
print(f1)
print(conf_matrix)
print(clas_report)

# 테스트 데이터에 대한 예측 확률 계산
y_pred_proba = model.predict_proba(x_test)[:,1]


# ROC 커브 계산
fpr, tpr, thresholds = roc_curve(y_test, y_pred)
roc_auc = auc(fpr, tpr)

# ROC 커브 그리기
plt.figure()
plt.plot(fpr, tpr, color='darkorange', lw=2, label='ROC curve (area = %0.2f)' % roc_auc)
plt.plot([0, 1], [0, 1], color='navy', lw=2, linestyle='--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver Operating Characteristic')
plt.legend(loc="lower right")
plt.show()
# Out:
# Iteration 1, loss = 0.37898815
# Iteration 2, loss = 0.28749819
# Iteration 3, loss = 0.27977482
# Iteration 4, loss = 0.27165279
# Iteration 5, loss = 0.26672891
# Iteration 6, loss = 0.26850189
# Iteration 7, loss = 0.26520906
# Iteration 8, loss = 0.26266007
# Iteration 9, loss = 0.26201876
# Iteration 10, loss = 0.26286869
# Iteration 11, loss = 0.25820332
# Iteration 12, loss = 0.25688930
# Iteration 13, loss = 0.25690735
# Iteration 14, loss = 0.25426998
# Iteration 15, loss = 0.25437153
# Iteration 16, loss = 0.25164020
# Iteration 17, loss = 0.25359801
# Iteration 18, loss = 0.24950745
# Iteration 19, loss = 0.24903240
# Iteration 20, loss = 0.24544896
# Iteration 21, loss = 0.24422681
# Iteration 22, loss = 0.24255822
# Iteration 23, loss = 0.24223106
# Iteration 24, loss = 0.23927068
# Iteration 25, loss = 0.23839547
# Iteration 26, loss = 0.23876572
# Iteration 27, loss = 0.23620423
# Iteration 28, loss = 0.23661679
# Iteration 113, loss = 0.20600709
# Iteration 114, loss = 0.21027723
# Iteration 115, loss = 0.20765997
# Iteration 116, loss = 0.20731482
# Iteration 117, loss = 0.20969570
# Iteration 118, loss = 0.20538797
# Iteration 119, loss = 0.20871060
# Iteration 120, loss = 0.20597993
# Iteration 121, loss = 0.20435642
# Iteration 122, loss = 0.20714035
# Iteration 123, loss = 0.20709207
# Iteration 124, loss = 0.20578971
# Iteration 125, loss = 0.20659568
# Iteration 126, loss = 0.20589711
# Iteration 127, loss = 0.20638800
# Iteration 128, loss = 0.20431227
# Iteration 129, loss = 0.20548342
# Iteration 130, loss = 0.20760179
# Iteration 131, loss = 0.20316259
# Iteration 132, loss = 0.20620867
# Iteration 133, loss = 0.20524685
# Iteration 134, loss = 0.20395063
# Iteration 135, loss = 0.20811264
# Iteration 136, loss = 0.20532405
# Iteration 137, loss = 0.20387883
# Iteration 138, loss = 0.20250955
# Iteration 139, loss = 0.20355898
# Iteration 140, loss = 0.20601572
# Iteration 141, loss = 0.20409962
# Iteration 142, loss = 0.20328948
# Iteration 143, loss = 0.20129561
# Iteration 144, loss = 0.20124421
# Iteration 145, loss = 0.20046822
# Iteration 146, loss = 0.20246701
# Iteration 147, loss = 0.20353998
# Iteration 148, loss = 0.19958102
# Iteration 149, loss = 0.20347784
# Iteration 150, loss = 0.20289076
# Iteration 151, loss = 0.19977068
# Iteration 152, loss = 0.20104340
# Iteration 153, loss = 0.19933203
# Iteration 154, loss = 0.20068462
# Iteration 155, loss = 0.19892152
# Iteration 156, loss = 0.20549386
# Iteration 157, loss = 0.20085998
# Iteration 158, loss = 0.19927777
# Iteration 159, loss = 0.19836854
# Iteration 160, loss = 0.19816028
# Iteration 161, loss = 0.19759680
# Iteration 162, loss = 0.20185587
# Iteration 163, loss = 0.20224074
# Iteration 164, loss = 0.19636511
# Iteration 165, loss = 0.19786357
# Iteration 166, loss = 0.19602747
# Iteration 167, loss = 0.19733473
# Iteration 168, loss = 0.19771320
# Iteration 169, loss = 0.19724091
# Iteration 170, loss = 0.19631420
# Iteration 171, loss = 0.19862252
# Iteration 172, loss = 0.19531242
# Iteration 173, loss = 0.19399160
# Iteration 174, loss = 0.19811884
# Iteration 175, loss = 0.19536003
# Iteration 176, loss = 0.19246390
# Iteration 177, loss = 0.20061289
# Iteration 178, loss = 0.19615164
# Iteration 179, loss = 0.19641114
# Iteration 180, loss = 0.19416201
# Iteration 181, loss = 0.19573575
# Iteration 182, loss = 0.20061275
# Iteration 183, loss = 0.19375951
# Iteration 184, loss = 0.19706999
# Iteration 185, loss = 0.19579521
# Iteration 186, loss = 0.19467125
# Iteration 187, loss = 0.19980745
# Training loss did not improve more than tol=0.000100 for 10 consecutive epochs. Stopping.
# 0.8177393722685737
# 0.8166533226581265
# 0.8161632326465293
# 0.8164082041020511
# [[4153  919]
#  [ 916 4080]]
#               precision    recall  f1-score   support
#
#            0       0.82      0.82      0.82      5072
#            1       0.82      0.82      0.82      4996
#
#     accuracy                           0.82     10068
#    macro avg       0.82      0.82      0.82     10068
# weighted avg       0.82      0.82      0.82     10068
